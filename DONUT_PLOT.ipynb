# %%
from matplotlib_venn import venn2
import numpy as np
import pandas as pd
data = pd.read_csv("Iris.csv")

# %%
import pandas as pd

# Iris veri setini yükleyin
iris = pd.read_csv('Iris.csv')

# Özelliklerin uzunluklarına bakın
feature_size = [len(iris['SepalLengthCm']), len(iris['SepalWidthCm']), len(iris['PetalLengthCm']), len(iris['PetalWidthCm'])]
print(feature_size)
# Out:
# [150, 150, 150, 150]

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

#ortadaki beyaz boşluğu yarat.
circle=Circle((0,0),0.5,color='white')
plt.pie(feature_size,labels=feature_names,colors=['red','green','blue','orange'])
p=plt.gcf()
p.gca().add_artist(circle)
plt.title('number of each Features')
plt.show()
